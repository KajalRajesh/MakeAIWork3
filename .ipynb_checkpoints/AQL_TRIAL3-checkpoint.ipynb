# %%
# import van het model uit resnet_cuda4.ipynb

# %%
from torchvision.models import resnet18
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

device = torch.device("cpu")
print(device)

num_classes = 4

#Resnet model
model = resnet18(pretrained=True)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, num_classes)


model.load_state_dict(torch.load('Resnet_Weigth_best.pth', map_location=torch.device('cpu')))
model = model.to(device)
model.eval()

# model = torch.load('Team_Complete_Model.pth')
# model = model.to(device)
# model.eval()
# Out:
# cpu
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=4, bias=True)
# )

# %%
image_size = 224
batch_size = 50

test_dir = "C:/Users/Lenovo/MakeAIWork3/images/Test1"

# Define the transformations for test data before entering the neural network
transform_test = transforms.Compose([
    transforms.Resize((image_size, image_size)),                     # Resize images to 224x224 pixels
    transforms.ToTensor(),                                           # Convert images to tensors
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # Normalize the images
])

# Load the test dataset
test_dataset = ImageFolder(test_dir, transform=transform_test)

# test_dataset.class_to_idx
# idx2class = {v: k for k, v in test_dataset.class_to_idx.items()}
# idx2class


# Create DataLoaders for managing the data batches
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)



def evaluate_acceptance_quality_batch(model, test_loader, device, threshold):
    model.eval()
    bad_images = []
    if perc_bad_images <= threshold:
        print("Klasse 1: naar supermarkt")
    elif threshold < perc_bad_images <= 6.5:
        print("Klasse 2: naar appelmoesfabriek")
    elif 6.6 < perc_bad_images <= 15:
        print("Klasse 3: naar appelstroopfabriek")
    else:
        print("Klasse 4: naar de varkens ermee!")

    print("Batch Statistics:")
    print("-----------------")
    print(f"Total Images: {total}")
    print(f"Correctly Classified Images (Good): {correct}")
    print(f"Percentage of Bad Images: {perc_bad_images}%")
    print(f"Average Loss: {running_loss / len(test_loader)}")
    
calculate_AQL = evaluate_acceptance_quality_batch(model, test_loader, device, 0.4)
# def evaluate_acceptance_quality_batch(model, test_loader, device, threshold):
#     model.eval()
#     correct = 0
#     total = 0
#     bad_images = []
#     criterion = nn.CrossEntropyLoss()
#     running_loss = 0.0

#     with torch.no_grad():
#         for images, labels in test_loader:
#             images = images.to(device)
#             labels = labels.to(device)

#             outputs = model(images)
#             _, predicted = torch.max(outputs.data, 1)

#             # Check if the predicted label is "good" (class index 0)
#             bad_images.extend([i for i, p in enumerate(predicted) if p != 1])

#             total += labels.size(0)
#             correct += (predicted == labels).sum().item()

#             loss = criterion(outputs, labels)
#             running_loss += loss.item()

#             # Print the labels
#             print("True Labels:", labels.tolist())
#             print("Predicted Labels:", predicted.tolist())

#     accuracy = 100.0 * correct / total
#     print(len(bad_images))
#     perc_bad_images = (len(bad_images) / total) * 100
#     print(perc_bad_images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 44
#      41     print(f"Percentage of Bad Images: {perc_bad_images}%")
#      42     print(f"Average Loss: {running_loss / len(test_loader)}")
# ---> 44 calculate_AQL = evaluate_acceptance_quality_batch(model, test_loader, device, 0.4)
#      45 # def evaluate_acceptance_quality_batch(model, test_loader, device, threshold):
#      46 #     model.eval()
#      47 #     correct = 0
#    (...)
#      76 #     perc_bad_images = (len(bad_images) / total) * 100
#      77 #     print(perc_bad_images)
#
# Cell In[21], line 28, in evaluate_acceptance_quality_batch(model, test_loader, device, threshold)
#      26 def evaluate_acceptance_quality_batch(model, test_loader, device, threshold):
#      27     model.eval()
# ---> 28     if perc_bad_images <= threshold:
#      29         print("Klasse 1: naar supermarkt")
#      30     elif threshold < perc_bad_images <= 6.5:
#
# NameError: name 'perc_bad_images' is not defined
